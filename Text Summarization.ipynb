# %% [markdown]
# # Import Libraries

# %%
import bs4 as bs 
import urllib.request
import re
import nltk
import heapq

# %% [markdown]
# # Fetch Data

# %%
source = urllib.request.urlopen('https://en.wikipedia.org/wiki/Technology').read()

# %%
soup = bs.BeautifulSoup(source,'lxml')

# %%
text = ""
for paragraph in soup.findAll('p'):
    text += paragraph.text

# %% [markdown]
# # Preprocessing the Text

# %%
text = re.sub(r'\[[0-9]*\]',' ',text)
text = re.sub(r'\s+',' ',text)
clean_text = text.lower()
clean_text = re.sub(r'\W',' ',clean_text)
clean_text = re.sub(r'\d',' ',clean_text)
clean_text = re.sub(r'\s+',' ',clean_text)

# %%
clean_text
# Out:
# ' technology science of craft from greek τέχνη techne art skill cunning of hand and λογία logia is the collection of techniques skills methods and processes used in the production of goods or services or in the accomplishment of objectives such as scientific investigation technology can be the knowledge of techniques processes and the like or it can be embedded in machines to allow for operation without detailed knowledge of their workings systems e g machines applying technology by taking an input changing it according to the system s use and then producing an outcome are referred to as technology systems or technological systems the simplest form of technology is the development and use of basic tools the prehistoric discovery of how to control fire and the later neolithic revolution increased the available sources of food and the invention of the wheel helped humans to travel in and control their environment developments in historic times including the printing press the telephone and the internet have lessened physical barriers to communication and allowed humans to interact freely on a global scale technology has many effects it has helped develop more advanced economies including today s global economy and has allowed the rise of a leisure class many technological processes produce unwanted by products known as pollution and deplete natural resources to the detriment of earth s environment innovations have always influenced the values of a society and raised new questions of the ethics of technology examples include the rise of the notion of efficiency in terms of human productivity and the challenges of bioethics philosophical debates have arisen over the use of technology with disagreements over whether technology improves the human condition or worsens it neo luddism anarcho primitivism and similar reactionary movements criticize the pervasiveness of technology arguing that it harms the environment and alienates people proponents of ideologies such as transhumanism and techno progressivism view continued technological progress as beneficial to society and the human condition the use of the term technology has changed significantly over the last years before the th century the term was uncommon in english and it was used either to refer to the description or study of the useful arts or to allude to technical education as in the massachusetts institute of technology chartered in the term technology rose to prominence in the th century in connection with the second industrial revolution the term s meanings changed in the early th century when american social scientists beginning with thorstein veblen translated ideas from the german concept of technik into technology in german and other european languages a distinction exists between technik and technologie that is absent in english which usually translates both terms as technology by the s technology referred not only to the study of the industrial arts but to the industrial arts themselves in the american sociologist read bain wrote that technology includes all tools machines utensils weapons instruments housing clothing communicating and transporting devices and the skills by which we produce and use them bain s definition remains common among scholars today especially social scientists scientists and engineers usually prefer to define technology as applied science rather than as the things that people make and use more recently scholars have borrowed from european philosophers of technique to extend the meaning of technology to various forms of instrumental reason as in foucault s work on technologies of the self techniques de soi dictionaries and scholars have offered a variety of definitions the merriam webster learner s dictionary offers a definition of the term the use of science in industry engineering etc to invent useful things or to solve problems and a machine piece of equipment method etc that is created by technology ursula franklin in her real world of te ...

# %% [markdown]
# # Tokenize Article into Sentence

# %%
sentences = nltk.sent_tokenize(text)

# %%
stopwords = nltk.corpus.stopwords.words('english')

# %%
stopwords
# Out:
# ['i',
#  'me',
#  'my',
#  'myself',
#  'we',
#  'our',
#  'ours',
#  'ourselves',
#  'you',
#  "you're",
#  "you've",
#  "you'll",
#  "you'd",
#  'your',
#  'yours',
#  'yourself',
#  'yourselves',
#  'he',
#  'him',
#  'his',
#  'himself',
#  'she',
#  "she's",
#  'her',
#  'hers',
#  'herself',
#  'it',
#  "it's",
#  'its',
#  'itself',
#  'they',
#  'them',
#  'their',
#  'theirs',
#  'themselves',
#  'what',
#  'which',
#  'who',
#  'whom',
#  'this',
#  'that',
#  "that'll",
#  'these',
#  'those',
#  'am',
#  'is',
#  'are',
#  'was',
#  'were',
#  'be',
#  'been',
#  'being',
#  'have',
#  'has',
#  'had',
#  'having',
#  'do',
#  'does',
#  'did',
#  'doing',
#  'a',
#  'an',
#  'the',
#  'and',
#  'but',
#  'if',
#  'or',
#  'because',
#  'as',
#  'until',
#  'while',
#  'of',
#  'at',
#  'by',
#  'for',
#  'with',
#  'about',
#  'against',
#  'between',
#  'into',
#  'through',
#  'during',
#  'before',
#  'after',
#  'above',
#  'below',
#  'to',
#  'from',
#  'up',
#  'down',
#  'in',
#  'out',
#  'on',
#  'off',
#  'over',
#  'under',
#  'again',
#  'further',
#  'then',
#  'once',
#  'here',
#  'there',
#  'when',
#  'where',
#  'why',
#  'how',
#  'all',
#  'any',
#  'both',
#  'each',
#  'few',
#  'more',
#  'most',
#  'other',
#  'some',
#  'such',
#  'no',
#  'nor',
#  'not',
#  'only',
#  'own',
#  'same',
#  'so',
#  'than',
#  'too',
#  'very',
#  's',
#  't',
#  'can',
#  'will',
#  'just',
#  'don',
#  "don't",
#  'should',
#  "should've",
#  'now',
#  'd',
#  'll',
#  'm',
#  'o',
#  're',
#  've',
#  'y',
#  'ain',
#  'aren',
#  "aren't",
#  'couldn',
#  "couldn't",
#  'didn',
#  "didn't",
#  'doesn',
#  "doesn't",
#  'hadn',
#  "hadn't",
#  'hasn',
#  "hasn't",
#  'haven',
#  "haven't",
#  'isn',
#  "isn't",
#  'ma',
#  'mightn',
#  "mightn't",
#  'mustn',
#  "mustn't",
#  'needn',
#  "needn't",
#  'shan',
#  "shan't",
#  'shouldn',
#  "shouldn't",
#  'wasn',
#  "wasn't",
#  'weren',
#  "weren't",
#  'won',
#  "won't",
#  'wouldn',
#  "wouldn't"]

# %% [markdown]
# # Build Histogram

# %%
word2count = {}
for word in nltk.word_tokenize(clean_text):
    if word not in stopwords:
        if word not in word2count.keys():
            word2count[word] = 1
        else:
            word2count[word] += 1

# %%
word2count
# Out:
# {'technology': 108,
#  'science': 25,
#  'craft': 1,
#  'greek': 2,
#  'τέχνη': 1,
#  'techne': 1,
#  'art': 2,
#  'skill': 1,
#  'cunning': 1,
#  'hand': 3,
#  'λογία': 1,
#  'logia': 1,
#  'collection': 2,
#  'techniques': 7,
#  'skills': 4,
#  'methods': 4,
#  'processes': 4,
#  'used': 18,
#  'production': 2,
#  'goods': 2,
#  'services': 1,
#  'accomplishment': 1,
#  'objectives': 1,
#  'scientific': 11,
#  'investigation': 1,
#  'knowledge': 14,
#  'like': 2,
#  'embedded': 1,
#  'machines': 10,
#  'allow': 2,
#  'operation': 1,
#  'without': 1,
#  'detailed': 1,
#  'workings': 1,
#  'systems': 5,
#  'e': 4,
#  'g': 3,
#  'applying': 1,
#  'taking': 1,
#  'input': 1,
#  'changing': 1,
#  'according': 6,
#  'system': 4,
#  'use': 31,
#  'producing': 1,
#  'outcome': 1,
#  'referred': 2,
#  'technological': 22,
#  'simplest': 1,
#  'form': 3,
#  'development': 5,
#  'basic': 5,
#  'tools': 23,
#  'prehistoric': 2,
#  'discovery': 10,
#  'control': 5,
#  'fire': 5,
#  'later': 6,
#  'neolithic': 5,
#  'revolution': 6,
#  'increased': 4,
#  'available': 2,
#  'sources': 2,
#  'food': 4,
#  'invention': 5,
#  'wheel': 10,
#  'helped': 4,
#  'humans': 14,
#  'travel': 1,
#  'environment': 3,
#  'developments': 1,
#  'historic': 1,
#  'times': 3,
#  'including': 7,
#  'printing': 2,
#  'press': 2,
#  'telephone': 2,
#  'internet': 10,
#  'lessened': 2,
#  'physical': 6,
#  'barriers': 3,
#  'communication': 4,
#  'allowed': 7,
#  'interact': 1,
#  'freely': 1,
#  'global': 2,
#  'scale': 2,
#  'many': 9,
#  'effects': 3,
#  'develop': 2,
#  'advanced': 2,
#  'economies': 1,
#  'today': 3,
#  'economy': 2,
#  'rise': 5,
#  'leisure': 1,
#  'class': 1,
#  'produce': 4,
#  'unwanted': 1,
#  'products': 4,
#  'known': 9,
#  'pollution': 1,
#  'deplete': 1,
#  'natural': 2,
#  'resources': 2,
#  'detriment': 1,
#  'earth': 1,
#  'innovations': 7,
#  'always': 3,
#  'influenced': 1,
#  'values': 2,
#  'society': 7,
#  'raised': 1,
#  'new': 16,
#  'questions': 3,
#  'ethics': 1,
#  'examples': 3,
#  'include': 5,
#  'notion': 4,
#  'efficiency': 1,
#  'terms': 2,
#  'human': 18,
#  'productivity': 1,
#  'challenges': 5,
#  'bioethics': 1,
#  'philosophical': 1,
#  'debates': 1,
#  'arisen': 2,
#  'disagreements': 1,
#  'whether': 1,
#  'improves': 1,
#  'condition': 4,
#  'worsens': 1,
#  'neo': 1,
#  'luddism': 1,
#  'anarcho': 1,
#  'primitivism': 1,
#  'similar': 2,
#  'reactionary': 1,
#  'movements': 1,
#  'criticize': 1,
#  'pervasiveness': 1,
#  'arguing': 1,
#  'harms': 1,
#  'alienates': 1,
#  'people': 5,
#  'proponents': 2,
#  'ideologies': 4,
#  'transhumanism': 2,
#  'techno': 6,
#  'progressivism': 1,
#  'view': 3,
#  'continued': 2,
#  'progress': 5,
#  'beneficial': 2,
#  'term': 9,
#  'changed': 3,
#  'significantly': 2,
#  'last': 2,
#  'years': 6,
#  'th': 10,
#  'century': 8,
#  'uncommon': 1,
#  'english': 2,
#  'either': 2,
#  'refer': 5,
#  'description': 1,
#  'study': 3,
#  'useful': 2,
#  'arts': 4,
#  'allude': 1,
#  'technical': 4,
#  'education': 2,
#  'massachusetts': 1,
#  'institute': 1,
#  'chartered': 1,
#  'rose': 1,
#  'prominence': 1,
#  'connection': 1,
#  'second': 3,
#  'industrial': 9,
#  'meanings': 1,
#  'early': 10,
#  'american': 6,
#  'social': 4,
#  'scientists': 8,
#  'beginning': 3,
#  'thorstein': 1,
#  'veblen': 1,
#  'translated': 1,
#  'ideas': 2,
#  'german': 2,
#  'concept': 2,
#  'technik': 2,
#  'european': 2,
#  'languages': 1,
#  'distinction': 2,
#  'exists': 1,
#  'technologie': 1,
#  'absent': 1,
#  'usually': 3,
#  'translates': 1,
#  'sociologist': 1,
#  'read': 2,
#  'bain': 2,
#  'wrote': 1,
#  'includes': 3,
#  'utensils': 1,
#  'weapons': 2,
#  'instruments': 1,
#  'housing': 1,
#  'clothing': 3,
#  'communicating': 1,
#  'transporting': 1,
#  'devices': 2,
#  'definition': 5,
#  'remains': 2,
#  'common': 3,
#  'among': 2,
#  'scholars': 4,
#  'especially': 3,
#  'engineers': 5,
#  'prefer': 1,
#  'define': 1,
#  'applied': 3,
#  'rather': 3,
#  'things': 3,
#  'make': 5,
#  'recently': 3,
#  'borrowed': 1,
#  'philosophers': 3,
#  'technique': 1,
#  'extend': 1,
#  'meaning': 1,
#  'various': 1,
#  'forms': 4,
#  'instrumental': 1,
#  'reason': 1,
#  'foucault': 1,
#  'work': 2,
#  'technologies': 9,
#  'self': 2,
#  'de': 1,
#  'soi': 1,
#  'dictionaries': 1,
#  'offered': 1,
#  'variety': 1,
#  'definitions': 2,
#  'merriam': 1,
#  'webster': 1,
#  'learner': 1,
#  'dictionary': 1,
#  'offers': 1,
#  'industry': 1,
#  'engineering': 9,
#  'etc': 2,
#  'invent': 1,
#  'solve': 4,
#  'problems': 8,
#  'machine': 1,
#  'piece': 1,
#  'equipment': 1,
#  'method': 1,
#  'created': 4,
#  'ursula': 1,
#  'franklin': 1,
#  'real': 2,
#  'world': 9,
#  'lecture': 1,
#  'gave': 1,
#  'another': 5,
#  'practice': 1,
#  'way': 9,
#  'around': 8,
#  'often': 10,
#  'imply': 1,
#  'specific': 3,
#  'field': 3,
#  'high': 5,
#  'consumer': 2,
#  'electronics': 1,
#  'whole': 2,
#  'bernard': 1,
#  'stiegler': 1,
#  'technics': 1,
#  'time': 6,
#  'defines': 2,
#  'two': 5,
#  'ways': 1,
#  'pursuit': 1,
#  'life': 6,
#  'means': 5,
#  'organized': 1,
#  'inorganic': 1,
#  'matter': 1,
#  'broadly': 3,
#  'defined': 2,
#  'entities': 1,
#  'material': 3,
#  'immaterial': 1,
#  'application': 4,
#  'mental': 2,
#  'effort': 2,
#  'order': 1,
#  'achieve': 2,
#  'value': 2,
#  'usage': 1,
#  'refers': 4,
#  'may': 9,
#  'far': 1,
#  'reaching': 1,
#  'simple': 3,
#  'crowbar': 1,
#  'wooden': 3,
#  'spoon': 1,
#  'complex': 11,
#  'space': 3,
#  'station': 1,
#  'particle': 1,
#  'accelerator': 1,
#  'need': 3,
#  'virtual': 1,
#  'computer': 3,
#  'software': 1,
#  'business': 1,
#  'fall': 2,
#  'w': 1,
#  'brian': 1,
#  'arthur': 1,
#  'similarly': 1,
#  'broad': 2,
#  'fulfill': 2,
#  'purpose': 1,
#  'word': 1,
#  'also': 18,
#  'context': 2,
#  'current': 3,
#  'state': 5,
#  'humanity': 4,
#  'combine': 1,
#  'desired': 1,
#  'needs': 2,
#  'satisfy': 2,
#  'wants': 1,
#  'raw': 1,
#  'materials': 1,
#  'combined': 2,
#  'medical': 1,
#  'respective': 1,
#  'viewed': 1,
#  'activity': 3,
#  'changes': 1,
#  'culture': 5,
#  'additionally': 2,
#  'math': 1,
#  'benefit': 1,
#  'modern': 6,
#  'example': 4,
#  'interaction': 1,
#  'result': 5,
#  'spawn': 1,
#  'subcultures': 2,
#  'cyberculture': 1,
#  'basis': 1,
#  'enhances': 1,
#  'creative': 2,
#  'help': 1,
#  'facilitate': 1,
#  'political': 2,
#  'oppression': 1,
#  'war': 4,
#  'via': 1,
#  'guns': 1,
#  'cultural': 3,
#  'predates': 1,
#  'formalize': 1,
#  'aspects': 1,
#  'endeavor': 1,
#  'clear': 2,
#  'systematic': 1,
#  'gained': 1,
#  'observation': 1,
#  'experimentation': 1,
#  'exclusively': 1,
#  'requirements': 1,
#  'utility': 2,
#  'usability': 1,
#  'safety': 1,
#  'citation': 1,
#  'needed': 4,
#  'goal': 1,
#  'oriented': 1,
#  'process': 4,
#  'designing': 1,
#  'making': 1,
#  'exploit': 1,
#  'phenomena': 1,
#  'practical': 2,
#  'using': 5,
#  'results': 2,
#  'draw': 1,
#  'upon': 1,
#  'fields': 5,
#  'mathematical': 1,
#  'linguistic': 1,
#  'historical': 1,
#  'consequence': 1,
#  'although': 2,
#  'precedes': 2,
#  'might': 1,
#  'flow': 1,
#  'electrons': 1,
#  'electrical': 1,
#  'conductors': 1,
#  'already': 3,
#  'existing': 1,
#  'found': 7,
#  'create': 3,
#  'semiconductors': 1,
#  'computers': 3,
#  'sense': 2,
#  'considered': 7,
#  'technologists': 1,
#  'three': 2,
#  'one': 8,
#  'purposes': 1,
#  'research': 4,
#  'reference': 1,
#  'exact': 2,
#  'relations': 1,
#  'particular': 1,
#  'debated': 1,
#  'historians': 1,
#  'policymakers': 1,
#  'late': 4,
#  'part': 4,
#  'debate': 2,
#  'inform': 1,
#  'funding': 1,
#  'immediate': 1,
#  'wake': 1,
#  'ii': 1,
#  'widely': 1,
#  'united': 2,
#  'states': 1,
#  'simply': 3,
#  'fund': 2,
#  'reap': 1,
#  'due': 2,
#  'articulation': 1,
#  'philosophy': 1,
#  'could': 7,
#  'explicitly': 1,
#  'vannevar': 1,
#  'bush': 1,
#  'treatise': 2,
#  'postwar': 1,
#  'policy': 3,
#  'endless': 1,
#  'frontier': 1,
#  'industries': 2,
#  'jobs': 6,
#  'require': 3,
#  'continuous': 2,
#  'additions': 1,
#  'laws': 1,
#  'nature': 3,
#  'essential': 1,
#  'obtained': 1,
#  'however': 5,
#  'came': 3,
#  'direct': 1,
#  'attack': 1,
#  'leading': 4,
#  'towards': 1,
#  'initiatives': 2,
#  'tasks': 1,
#  'resisted': 1,
#  'community': 1,
#  'issue': 2,
#  'contentious': 1,
#  'though': 1,
#  'analysts': 1,
#  'resist': 1,
#  'model': 1,
#  'partly': 1,
#  'evolution': 2,
#  'evolved': 1,
#  'species': 2,
#  'foraging': 2,
#  'hominids': 2,
#  'bipedal': 1,
#  'brain': 2,
#  'mass': 3,
#  'approximately': 3,
#  'third': 2,
#  'tool': 3,
#  'remained': 1,
#  'relatively': 2,
#  'unchanged': 1,
#  'history': 3,
#  'ago': 3,
#  'set': 1,
#  'behaviors': 1,
#  'emerged': 2,
#  'believed': 2,
#  'archaeologists': 2,
#  'connected': 1,
#  'emergence': 2,
#  'fully': 1,
#  'language': 1,
#  'started': 1,
#  'primitive': 1,
#  'stone': 9,
#  'millions': 1,
#  'earliest': 3,
#  'little': 1,
#  'fractured': 1,
#  'rock': 1,
#  'pressure': 1,
#  'flaking': 1,
#  'provided': 2,
#  'much': 2,
#  'finer': 1,
#  'utilization': 1,
#  'energy': 3,
#  'source': 1,
#  'profound': 1,
#  'uses': 3,
#  'turning': 1,
#  'point': 3,
#  'humankind': 2,
#  'date': 3,
#  'evidence': 2,
#  'burnt': 1,
#  'animal': 3,
#  'bones': 1,
#  'cradle': 1,
#  'suggests': 2,
#  'domestication': 1,
#  'occurred': 2,
#  'scholarly': 1,
#  'consensus': 1,
#  'indicates': 1,
#  'homo': 2,
#  'erectus': 1,
#  'controlled': 1,
#  'ka': 4,
#  'fueled': 1,
#  'wood': 3,
#  'charcoal': 2,
#  'cook': 1,
#  'increase': 3,
#  'digestibility': 1,
#  'improving': 2,
#  'nutrient': 1,
#  'broadening': 1,
#  'number': 3,
#  'foods': 1,
#  'eaten': 1,
#  'advances': 4,
#  'made': 4,
#  'paleolithic': 2,
#  'era': 4,
#  'shelter': 1,
#  'adoption': 2,
#  'dated': 1,
#  'exactly': 1,
#  'key': 2,
#  'progressed': 1,
#  'dwellings': 1,
#  'became': 2,
#  'sophisticated': 2,
#  'elaborate': 1,
#  'constructing': 1,
#  'temporary': 1,
#  'huts': 1,
#  'adapted': 1,
#  'fur': 1,
#  'hides': 1,
#  'hunted': 1,
#  'animals': 1,
#  'expand': 1,
#  'colder': 1,
#  'regions': 1,
#  'began': 3,
#  'migrate': 1,
#  'africa': 1,
#  'continents': 1,
#  'eurasia': 1,
#  'ascent': 1,
#  'earnest': 1,
#  'period': 4,
#  'age': 2,
#  'polished': 2,
#  'axes': 2,
#  'major': 2,
#  'advance': 1,
#  'forest': 1,
#  'clearance': 1,
#  'large': 2,
#  'farms': 1,
#  'greatly': 2,
#  'originally': 1,
#  'preceding': 1,
#  'mesolithic': 1,
#  'areas': 3,
#  'ireland': 1,
#  'agriculture': 2,
#  'fed': 1,
#  'larger': 1,
#  'populations': 1,
#  'transition': 1,
#  'sedentism': 1,
#  'simultaneously': 2,
#  'raising': 2,
#  'children': 2,
#  'infants': 1,
#  'longer': 1,
#  'carried': 1,
#  'nomadic': 1,
#  'ones': 2,
#  'must': 1,
#  'contribute': 1,
#  'labor': 5,
#  'crops': 1,
#  'readily': 1,
#  'hunter': 1,
#  'gatherer': 1,
#  'population': 1,
#  'availability': 2,
#  'specialization': 1,
#  'triggered': 1,
#  'progression': 1,
#  'villages': 1,
#  'first': 10,
#  'cities': 1,
#  'uruk': 1,
#  'civilizations': 1,
#  'sumer': 1,
#  'specifically': 1,
#  'increasingly': 4,
#  'hierarchical': 1,
#  'structures': 1,
#  'specialized': 1,
#  'trade': 3,
#  'amongst': 2,
#  'adjacent': 1,
#  'cultures': 1,
#  'collective': 1,
#  'action': 1,
#  'overcome': 2,
#  'environmental': 3,
#  'irrigation': 3,
#  'thought': 1,
#  'played': 1,
#  'role': 3,
#  'continuing': 1,
#  'improvements': 1,
#  'led': 5,
#  'furnace': 1,
#  'bellows': 1,
#  'ability': 2,
#  'smelt': 1,
#  'forge': 1,
#  'gold': 1,
#  'copper': 5,
#  'silver': 1,
#  'lead': 2,
#  'native': 3,
#  'metals': 2,
#  'pure': 1,
#  'advantages': 1,
#  'bone': 1,
#  'quickly': 1,
#  'apparent': 1,
#  'probably': 3,
#  'near': 1,
#  'naturally': 1,
#  'occur': 2,
#  'amounts': 2,
#  'ores': 1,
#  'quite': 1,
#  'metal': 1,
#  'easily': 2,
#  'burned': 1,
#  'fires': 1,
#  'eventually': 2,
#  'working': 1,
#  'alloys': 2,
#  'bronze': 1,
#  'brass': 1,
#  'bce': 14,
#  'iron': 1,
#  'steel': 1,
#  'dates': 2,
#  'meanwhile': 1,
#  'learning': 2,
#  'harness': 1,
#  'wind': 1,
#  'power': 6,
#  'sailing': 1,
#  'ship': 2,
#  'record': 1,
#  'sail': 1,
#  'nile': 2,
#  'boat': 1,
#  'dating': 3,
#  'millennium': 1,
#  'egyptians': 1,
#  'annual': 1,
#  'flooding': 1,
#  'irrigate': 1,
#  'lands': 1,
#  'gradually': 1,
#  'regulate': 1,
#  'purposely': 1,
#  'built': 4,
#  'channels': 1,
#  'catch': 1,
#  'basins': 1,
#  'ancient': 6,
#  'sumerians': 2,
#  'mesopotamia': 3,
#  'canals': 1,
#  'levees': 1,
#  'divert': 1,
#  'water': 5,
#  'tigris': 1,
#  'euphrates': 1,
#  'rivers': 1,
#  'invented': 4,
#  'independently': 1,
#  'nearly': 3,
#  'present': 1,
#  'day': 1,
#  'iraq': 1,
#  'northern': 1,
#  'caucasus': 1,
#  'maykop': 1,
#  'central': 1,
#  'europe': 1,
#  'estimates': 3,
#  'range': 1,
#  'experts': 1,
#  'putting': 1,
#  'closer': 1,
#  'oldest': 3,
#  'artifacts': 1,
#  'drawings': 2,
#  'depicting': 1,
#  'wheeled': 3,
#  'carts': 2,
#  'millennia': 1,
#  'ljubljana': 1,
#  'marshes': 1,
#  'slovenia': 1,
#  'revolutionized': 2,
#  'take': 1,
#  'long': 4,
#  'discover': 1,
#  'wagons': 1,
#  'carry': 1,
#  'heavy': 2,
#  'loads': 1,
#  'potter': 1,
#  'pottery': 3,
#  'city': 2,
#  'ur': 2,
#  'even': 4,
#  'older': 2,
#  'fragments': 1,
#  'thrown': 1,
#  'area': 1,
#  'fast': 1,
#  'rotary': 1,
#  'potters': 1,
#  'wheels': 2,
#  'enabled': 1,
#  'transformer': 1,
#  'windmills': 2,
#  'treadmills': 1,
#  'nonhuman': 1,
#  'derived': 1,
#  'travois': 1,
#  'iran': 1,
#  'constructed': 1,
#  'roadways': 1,
#  'paved': 3,
#  'streets': 1,
#  'circa': 1,
#  'timber': 1,
#  'roads': 1,
#  'swamps': 1,
#  'glastonbury': 1,
#  'england': 1,
#  'distance': 1,
#  'road': 6,
#  'spanned': 1,
#  'miles': 1,
#  'persian': 1,
#  'gulf': 1,
#  'mediterranean': 1,
#  'sea': 1,
#  'partially': 1,
#  'maintained': 1,
#  'minoans': 1,
#  'island': 3,
#  'crete': 1,
#  'fifty': 1,
#  'kilometer': 1,
#  'thirty': 1,
#  'mile': 1,
#  'palace': 3,
#  'gortyn': 1,
#  'south': 1,
#  'side': 3,
#  'mountains': 1,
#  'knossos': 2,
#  'north': 1,
#  'unlike': 1,
#  'earlier': 1,
#  'minoan': 3,
#  'completely': 1,
#  'private': 2,
#  'homes': 2,
#  'running': 1,
#  'bathtub': 1,
#  'virtually': 1,
#  'identical': 1,
#  'unearthed': 1,
#  'several': 2,
#  'toilets': 2,
#  'flushed': 1,
#  'pouring': 1,
#  'drain': 1,
#  'romans': 2,
#  'public': 2,
#  'flush': 1,
#  'emptied': 1,
#  'extensive': 1,
#  'sewage': 1,
#  'primary': 1,
#  'sewer': 1,
#  'rome': 1,
#  'cloaca': 1,
#  'maxima': 1,
#  'construction': 4,
#  'sixth': 1,
#  'still': 3,
#  'aqueducts': 2,
#  'transport': 3,
#  'across': 1,
#  'distances': 1,
#  'roman': 4,
#  'aqueduct': 2,
#  'eleventh': 1,
#  'final': 1,
#  'ce': 1,
#  'put': 1,
#  'together': 1,
#  'extended': 1,
#  'kilometers': 2,
#  'less': 1,
#  'seventy': 1,
#  'ground': 1,
#  'supported': 1,
#  'arches': 1,
#  'middle': 1,
#  'ages': 1,
#  'silk': 1,
#  'horse': 1,
#  'collar': 1,
#  'horseshoes': 1,
#  'hundred': 1,
#  'empire': 1,
#  'medieval': 1,
#  'saw': 2,
#  'lever': 1,
#  'screw': 1,
#  'pulley': 1,
#  'complicated': 1,
#  'wheelbarrow': 1,
#  'clocks': 1,
#  'renaissance': 1,
#  'brought': 3,
#  'forth': 1,
#  'facilitated': 1,
#  'greater': 1,
#  'associated': 2,
#  'cycle': 1,
#  'mutual': 1,
#  'advancement': 2,
#  'advancements': 2,
#  'steady': 1,
#  'supply': 2,
#  'followed': 1,
#  'wider': 1,
#  'starting': 1,
#  'kingdom': 1,
#  'great': 1,
#  'particularly': 3,
#  'manufacturing': 2,
#  'mining': 1,
#  'metallurgy': 1,
#  'driven': 1,
#  'steam': 1,
#  'took': 1,
#  'step': 1,
#  'harnessing': 1,
#  'electricity': 1,
#  'electric': 1,
#  'motor': 1,
#  'light': 1,
#  'bulb': 1,
#  'countless': 1,
#  'others': 1,
#  'concepts': 2,
#  'powered': 1,
#  'flight': 1,
#  'medicine': 3,
#  'chemistry': 1,
#  'physics': 2,
#  'skyscrapers': 1,
#  'urban': 1,
#  'whose': 1,
#  'inhabitants': 1,
#  'rely': 1,
#  'motors': 1,
#  'improved': 1,
#  'telegraph': 1,
#  'radio': 1,
#  'television': 1,
#  'centuries': 1,
#  'transportation': 2,
#  'airplane': 1,
#  'automobile': 1,
#  'host': 1,
#  'nuclear': 3,
#  'fission': 1,
#  'miniaturized': 1,
#  'utilizing': 1,
#  'transistors': 1,
#  'integrated': 1,
#  'circuits': 1,
#  'information': 3,
#  'subsequently': 1,
#  'creation': 1,
#  'ushered': 1,
#  'able': 2,
#  'explore': 1,
#  'satellites': 1,
#  'telecommunication': 1,
#  'manned': 1,
#  'missions': 1,
#  'going': 2,
#  'moon': 1,
#  'open': 2,
#  'heart': 1,
#  'surgery': 1,
#  'stem': 1,
#  'cell': 1,
#  'therapy': 1,
#  'along': 1,
#  'medications': 1,
#  'treatments': 1,
#  'organizations': 1,
#  'maintain': 1,
#  'entire': 2,
#  'support': 3,
#  'succeeding': 1,
#  'generations': 1,
#  'relies': 1,
#  'training': 2,
#  'designers': 1,
#  'builders': 1,
#  'maintainers': 1,
#  'users': 1,
#  'general': 2,
#  'moreover': 1,
#  'become': 2,
#  'architecture': 1,
#  'generally': 3,
#  'technicism': 2,
#  'belief': 1,
#  'societies': 6,
#  'taken': 2,
#  'extreme': 1,
#  'reflects': 1,
#  'fundamental': 3,
#  'attitude': 1,
#  'seeks': 1,
#  'reality': 1,
#  'resolve': 1,
#  'words': 1,
#  'beings': 2,
#  'someday': 1,
#  'master': 1,
#  'possibly': 1,
#  'future': 5,
#  ...}

# %%
for key in word2count.keys():
    word2count[key] = word2count[key]/max(word2count.values())

# %%
word2count
# Out:
# {'technology': 1.0,
#  'science': 0.8064516129032258,
#  'craft': 0.03225806451612903,
#  'greek': 0.06451612903225806,
#  'τέχνη': 0.03225806451612903,
#  'techne': 0.03225806451612903,
#  'art': 0.06451612903225806,
#  'skill': 0.03225806451612903,
#  'cunning': 0.03225806451612903,
#  'hand': 0.0967741935483871,
#  'λογία': 0.03225806451612903,
#  'logia': 0.03225806451612903,
#  'collection': 0.06451612903225806,
#  'techniques': 0.22580645161290322,
#  'skills': 0.12903225806451613,
#  'methods': 0.12903225806451613,
#  'processes': 0.12903225806451613,
#  'used': 0.5806451612903226,
#  'production': 0.06451612903225806,
#  'goods': 0.06451612903225806,
#  'services': 0.03225806451612903,
#  'accomplishment': 0.03225806451612903,
#  'objectives': 0.03225806451612903,
#  'scientific': 0.3548387096774194,
#  'investigation': 0.03225806451612903,
#  'knowledge': 0.45161290322580644,
#  'like': 0.06451612903225806,
#  'embedded': 0.03225806451612903,
#  'machines': 0.3225806451612903,
#  'allow': 0.06451612903225806,
#  'operation': 0.03225806451612903,
#  'without': 0.03225806451612903,
#  'detailed': 0.03225806451612903,
#  'workings': 0.03225806451612903,
#  'systems': 0.16129032258064516,
#  'e': 0.12903225806451613,
#  'g': 0.0967741935483871,
#  'applying': 0.03225806451612903,
#  'taking': 0.03225806451612903,
#  'input': 0.03225806451612903,
#  'changing': 0.03225806451612903,
#  'according': 0.1935483870967742,
#  'system': 0.12903225806451613,
#  'use': 1.0,
#  'producing': 0.043478260869565216,
#  'outcome': 0.043478260869565216,
#  'referred': 0.08695652173913043,
#  'technological': 0.9565217391304348,
#  'simplest': 0.043478260869565216,
#  'form': 0.13043478260869565,
#  'development': 0.21739130434782608,
#  'basic': 0.21739130434782608,
#  'tools': 1.0,
#  'prehistoric': 0.1111111111111111,
#  'discovery': 0.5555555555555556,
#  'control': 0.2777777777777778,
#  'fire': 0.2777777777777778,
#  'later': 0.3333333333333333,
#  'neolithic': 0.2777777777777778,
#  'revolution': 0.3333333333333333,
#  'increased': 0.2222222222222222,
#  'available': 0.1111111111111111,
#  'sources': 0.1111111111111111,
#  'food': 0.2222222222222222,
#  'invention': 0.2777777777777778,
#  'wheel': 0.5555555555555556,
#  'helped': 0.2222222222222222,
#  'humans': 0.7777777777777778,
#  'travel': 0.05555555555555555,
#  'environment': 0.16666666666666666,
#  'developments': 0.05555555555555555,
#  'historic': 0.05555555555555555,
#  'times': 0.16666666666666666,
#  'including': 0.3888888888888889,
#  'printing': 0.1111111111111111,
#  'press': 0.1111111111111111,
#  'telephone': 0.1111111111111111,
#  'internet': 0.5555555555555556,
#  'lessened': 0.1111111111111111,
#  'physical': 0.3333333333333333,
#  'barriers': 0.16666666666666666,
#  'communication': 0.2222222222222222,
#  'allowed': 0.3888888888888889,
#  'interact': 0.05555555555555555,
#  'freely': 0.05555555555555555,
#  'global': 0.1111111111111111,
#  'scale': 0.1111111111111111,
#  'many': 0.5,
#  'effects': 0.16666666666666666,
#  'develop': 0.1111111111111111,
#  'advanced': 0.1111111111111111,
#  'economies': 0.05555555555555555,
#  'today': 0.16666666666666666,
#  'economy': 0.1111111111111111,
#  'rise': 0.2777777777777778,
#  'leisure': 0.05555555555555555,
#  'class': 0.05555555555555555,
#  'produce': 0.2222222222222222,
#  'unwanted': 0.05555555555555555,
#  'products': 0.2222222222222222,
#  'known': 0.5,
#  'pollution': 0.05555555555555555,
#  'deplete': 0.05555555555555555,
#  'natural': 0.1111111111111111,
#  'resources': 0.1111111111111111,
#  'detriment': 0.05555555555555555,
#  'earth': 0.05555555555555555,
#  'innovations': 0.3888888888888889,
#  'always': 0.16666666666666666,
#  'influenced': 0.05555555555555555,
#  'values': 0.1111111111111111,
#  'society': 0.3888888888888889,
#  'raised': 0.05555555555555555,
#  'new': 0.8888888888888888,
#  'questions': 0.16666666666666666,
#  'ethics': 0.05555555555555555,
#  'examples': 0.16666666666666666,
#  'include': 0.2777777777777778,
#  'notion': 0.2222222222222222,
#  'efficiency': 0.05555555555555555,
#  'terms': 0.1111111111111111,
#  'human': 1.0,
#  'productivity': 0.05555555555555555,
#  'challenges': 0.2777777777777778,
#  'bioethics': 0.05555555555555555,
#  'philosophical': 0.05555555555555555,
#  'debates': 0.05555555555555555,
#  'arisen': 0.1111111111111111,
#  'disagreements': 0.05555555555555555,
#  'whether': 0.05555555555555555,
#  'improves': 0.05555555555555555,
#  'condition': 0.2222222222222222,
#  'worsens': 0.05555555555555555,
#  'neo': 0.05555555555555555,
#  'luddism': 0.05555555555555555,
#  'anarcho': 0.05555555555555555,
#  'primitivism': 0.05555555555555555,
#  'similar': 0.1111111111111111,
#  'reactionary': 0.05555555555555555,
#  'movements': 0.05555555555555555,
#  'criticize': 0.05555555555555555,
#  'pervasiveness': 0.05555555555555555,
#  'arguing': 0.05555555555555555,
#  'harms': 0.05555555555555555,
#  'alienates': 0.05555555555555555,
#  'people': 0.2777777777777778,
#  'proponents': 0.1111111111111111,
#  'ideologies': 0.2222222222222222,
#  'transhumanism': 0.1111111111111111,
#  'techno': 0.3333333333333333,
#  'progressivism': 0.05555555555555555,
#  'view': 0.16666666666666666,
#  'continued': 0.1111111111111111,
#  'progress': 0.2777777777777778,
#  'beneficial': 0.1111111111111111,
#  'term': 0.5,
#  'changed': 0.16666666666666666,
#  'significantly': 0.1111111111111111,
#  'last': 0.1111111111111111,
#  'years': 0.3333333333333333,
#  'th': 0.5555555555555556,
#  'century': 0.4444444444444444,
#  'uncommon': 0.05555555555555555,
#  'english': 0.1111111111111111,
#  'either': 0.1111111111111111,
#  'refer': 0.2777777777777778,
#  'description': 0.05555555555555555,
#  'study': 0.16666666666666666,
#  'useful': 0.1111111111111111,
#  'arts': 0.2222222222222222,
#  'allude': 0.05555555555555555,
#  'technical': 0.2222222222222222,
#  'education': 0.1111111111111111,
#  'massachusetts': 0.05555555555555555,
#  'institute': 0.05555555555555555,
#  'chartered': 0.05555555555555555,
#  'rose': 0.05555555555555555,
#  'prominence': 0.05555555555555555,
#  'connection': 0.05555555555555555,
#  'second': 0.16666666666666666,
#  'industrial': 0.5,
#  'meanings': 0.05555555555555555,
#  'early': 0.5555555555555556,
#  'american': 0.3333333333333333,
#  'social': 0.2222222222222222,
#  'scientists': 0.4444444444444444,
#  'beginning': 0.16666666666666666,
#  'thorstein': 0.05555555555555555,
#  'veblen': 0.05555555555555555,
#  'translated': 0.05555555555555555,
#  'ideas': 0.1111111111111111,
#  'german': 0.1111111111111111,
#  'concept': 0.1111111111111111,
#  'technik': 0.1111111111111111,
#  'european': 0.1111111111111111,
#  'languages': 0.05555555555555555,
#  'distinction': 0.1111111111111111,
#  'exists': 0.05555555555555555,
#  'technologie': 0.05555555555555555,
#  'absent': 0.05555555555555555,
#  'usually': 0.16666666666666666,
#  'translates': 0.05555555555555555,
#  'sociologist': 0.05555555555555555,
#  'read': 0.1111111111111111,
#  'bain': 0.1111111111111111,
#  'wrote': 0.05555555555555555,
#  'includes': 0.16666666666666666,
#  'utensils': 0.05555555555555555,
#  'weapons': 0.1111111111111111,
#  'instruments': 0.05555555555555555,
#  'housing': 0.05555555555555555,
#  'clothing': 0.16666666666666666,
#  'communicating': 0.05555555555555555,
#  'transporting': 0.05555555555555555,
#  'devices': 0.1111111111111111,
#  'definition': 0.2777777777777778,
#  'remains': 0.1111111111111111,
#  'common': 0.16666666666666666,
#  'among': 0.1111111111111111,
#  'scholars': 0.2222222222222222,
#  'especially': 0.16666666666666666,
#  'engineers': 0.2777777777777778,
#  'prefer': 0.05555555555555555,
#  'define': 0.05555555555555555,
#  'applied': 0.16666666666666666,
#  'rather': 0.16666666666666666,
#  'things': 0.16666666666666666,
#  'make': 0.2777777777777778,
#  'recently': 0.16666666666666666,
#  'borrowed': 0.05555555555555555,
#  'philosophers': 0.16666666666666666,
#  'technique': 0.05555555555555555,
#  'extend': 0.05555555555555555,
#  'meaning': 0.05555555555555555,
#  'various': 0.05555555555555555,
#  'forms': 0.2222222222222222,
#  'instrumental': 0.05555555555555555,
#  'reason': 0.05555555555555555,
#  'foucault': 0.05555555555555555,
#  'work': 0.1111111111111111,
#  'technologies': 0.5,
#  'self': 0.1111111111111111,
#  'de': 0.05555555555555555,
#  'soi': 0.05555555555555555,
#  'dictionaries': 0.05555555555555555,
#  'offered': 0.05555555555555555,
#  'variety': 0.05555555555555555,
#  'definitions': 0.1111111111111111,
#  'merriam': 0.05555555555555555,
#  'webster': 0.05555555555555555,
#  'learner': 0.05555555555555555,
#  'dictionary': 0.05555555555555555,
#  'offers': 0.05555555555555555,
#  'industry': 0.05555555555555555,
#  'engineering': 0.5,
#  'etc': 0.1111111111111111,
#  'invent': 0.05555555555555555,
#  'solve': 0.2222222222222222,
#  'problems': 0.4444444444444444,
#  'machine': 0.05555555555555555,
#  'piece': 0.05555555555555555,
#  'equipment': 0.05555555555555555,
#  'method': 0.05555555555555555,
#  'created': 0.2222222222222222,
#  'ursula': 0.05555555555555555,
#  'franklin': 0.05555555555555555,
#  'real': 0.1111111111111111,
#  'world': 0.5,
#  'lecture': 0.05555555555555555,
#  'gave': 0.05555555555555555,
#  'another': 0.2777777777777778,
#  'practice': 0.05555555555555555,
#  'way': 0.5,
#  'around': 0.4444444444444444,
#  'often': 0.5555555555555556,
#  'imply': 0.05555555555555555,
#  'specific': 0.16666666666666666,
#  'field': 0.16666666666666666,
#  'high': 0.2777777777777778,
#  'consumer': 0.1111111111111111,
#  'electronics': 0.05555555555555555,
#  'whole': 0.1111111111111111,
#  'bernard': 0.05555555555555555,
#  'stiegler': 0.05555555555555555,
#  'technics': 0.05555555555555555,
#  'time': 0.3333333333333333,
#  'defines': 0.1111111111111111,
#  'two': 0.2777777777777778,
#  'ways': 0.05555555555555555,
#  'pursuit': 0.05555555555555555,
#  'life': 0.3333333333333333,
#  'means': 0.2777777777777778,
#  'organized': 0.05555555555555555,
#  'inorganic': 0.05555555555555555,
#  'matter': 0.05555555555555555,
#  'broadly': 0.16666666666666666,
#  'defined': 0.1111111111111111,
#  'entities': 0.05555555555555555,
#  'material': 0.16666666666666666,
#  'immaterial': 0.05555555555555555,
#  'application': 0.2222222222222222,
#  'mental': 0.1111111111111111,
#  'effort': 0.1111111111111111,
#  'order': 0.05555555555555555,
#  'achieve': 0.1111111111111111,
#  'value': 0.1111111111111111,
#  'usage': 0.05555555555555555,
#  'refers': 0.2222222222222222,
#  'may': 0.5,
#  'far': 0.05555555555555555,
#  'reaching': 0.05555555555555555,
#  'simple': 0.16666666666666666,
#  'crowbar': 0.05555555555555555,
#  'wooden': 0.16666666666666666,
#  'spoon': 0.05555555555555555,
#  'complex': 0.6111111111111112,
#  'space': 0.16666666666666666,
#  'station': 0.05555555555555555,
#  'particle': 0.05555555555555555,
#  'accelerator': 0.05555555555555555,
#  'need': 0.16666666666666666,
#  'virtual': 0.05555555555555555,
#  'computer': 0.16666666666666666,
#  'software': 0.05555555555555555,
#  'business': 0.05555555555555555,
#  'fall': 0.1111111111111111,
#  'w': 0.05555555555555555,
#  'brian': 0.05555555555555555,
#  'arthur': 0.05555555555555555,
#  'similarly': 0.05555555555555555,
#  'broad': 0.1111111111111111,
#  'fulfill': 0.1111111111111111,
#  'purpose': 0.05555555555555555,
#  'word': 0.05555555555555555,
#  'also': 1.0,
#  'context': 0.14285714285714285,
#  'current': 0.21428571428571427,
#  'state': 0.35714285714285715,
#  'humanity': 0.2857142857142857,
#  'combine': 0.07142857142857142,
#  'desired': 0.07142857142857142,
#  'needs': 0.14285714285714285,
#  'satisfy': 0.14285714285714285,
#  'wants': 0.07142857142857142,
#  'raw': 0.07142857142857142,
#  'materials': 0.07142857142857142,
#  'combined': 0.14285714285714285,
#  'medical': 0.07142857142857142,
#  'respective': 0.07142857142857142,
#  'viewed': 0.07142857142857142,
#  'activity': 0.21428571428571427,
#  'changes': 0.07142857142857142,
#  'culture': 0.35714285714285715,
#  'additionally': 0.14285714285714285,
#  'math': 0.07142857142857142,
#  'benefit': 0.07142857142857142,
#  'modern': 0.42857142857142855,
#  'example': 0.2857142857142857,
#  'interaction': 0.07142857142857142,
#  'result': 0.35714285714285715,
#  'spawn': 0.07142857142857142,
#  'subcultures': 0.14285714285714285,
#  'cyberculture': 0.07142857142857142,
#  'basis': 0.07142857142857142,
#  'enhances': 0.07142857142857142,
#  'creative': 0.14285714285714285,
#  'help': 0.07142857142857142,
#  'facilitate': 0.07142857142857142,
#  'political': 0.14285714285714285,
#  'oppression': 0.07142857142857142,
#  'war': 0.2857142857142857,
#  'via': 0.07142857142857142,
#  'guns': 0.07142857142857142,
#  'cultural': 0.21428571428571427,
#  'predates': 0.07142857142857142,
#  'formalize': 0.07142857142857142,
#  'aspects': 0.07142857142857142,
#  'endeavor': 0.07142857142857142,
#  'clear': 0.14285714285714285,
#  'systematic': 0.07142857142857142,
#  'gained': 0.07142857142857142,
#  'observation': 0.07142857142857142,
#  'experimentation': 0.07142857142857142,
#  'exclusively': 0.07142857142857142,
#  'requirements': 0.07142857142857142,
#  'utility': 0.14285714285714285,
#  'usability': 0.07142857142857142,
#  'safety': 0.07142857142857142,
#  'citation': 0.07142857142857142,
#  'needed': 0.2857142857142857,
#  'goal': 0.07142857142857142,
#  'oriented': 0.07142857142857142,
#  'process': 0.2857142857142857,
#  'designing': 0.07142857142857142,
#  'making': 0.07142857142857142,
#  'exploit': 0.07142857142857142,
#  'phenomena': 0.07142857142857142,
#  'practical': 0.14285714285714285,
#  'using': 0.35714285714285715,
#  'results': 0.14285714285714285,
#  'draw': 0.07142857142857142,
#  'upon': 0.07142857142857142,
#  'fields': 0.35714285714285715,
#  'mathematical': 0.07142857142857142,
#  'linguistic': 0.07142857142857142,
#  'historical': 0.07142857142857142,
#  'consequence': 0.07142857142857142,
#  'although': 0.14285714285714285,
#  'precedes': 0.14285714285714285,
#  'might': 0.07142857142857142,
#  'flow': 0.07142857142857142,
#  'electrons': 0.07142857142857142,
#  'electrical': 0.07142857142857142,
#  'conductors': 0.07142857142857142,
#  'already': 0.21428571428571427,
#  'existing': 0.07142857142857142,
#  'found': 0.5,
#  'create': 0.21428571428571427,
#  'semiconductors': 0.07142857142857142,
#  'computers': 0.21428571428571427,
#  'sense': 0.14285714285714285,
#  'considered': 0.5,
#  'technologists': 0.07142857142857142,
#  'three': 0.14285714285714285,
#  'one': 0.5714285714285714,
#  'purposes': 0.07142857142857142,
#  'research': 0.2857142857142857,
#  'reference': 0.07142857142857142,
#  'exact': 0.14285714285714285,
#  'relations': 0.07142857142857142,
#  'particular': 0.07142857142857142,
#  'debated': 0.07142857142857142,
#  'historians': 0.07142857142857142,
#  'policymakers': 0.07142857142857142,
#  'late': 0.2857142857142857,
#  'part': 0.2857142857142857,
#  'debate': 0.14285714285714285,
#  'inform': 0.07142857142857142,
#  'funding': 0.07142857142857142,
#  'immediate': 0.07142857142857142,
#  'wake': 0.07142857142857142,
#  'ii': 0.07142857142857142,
#  'widely': 0.07142857142857142,
#  'united': 0.14285714285714285,
#  'states': 0.07142857142857142,
#  'simply': 0.21428571428571427,
#  'fund': 0.14285714285714285,
#  'reap': 0.07142857142857142,
#  'due': 0.14285714285714285,
#  'articulation': 0.07142857142857142,
#  'philosophy': 0.07142857142857142,
#  'could': 0.5,
#  'explicitly': 0.07142857142857142,
#  'vannevar': 0.07142857142857142,
#  'bush': 0.07142857142857142,
#  'treatise': 0.14285714285714285,
#  'postwar': 0.07142857142857142,
#  'policy': 0.21428571428571427,
#  'endless': 0.07142857142857142,
#  'frontier': 0.07142857142857142,
#  'industries': 0.14285714285714285,
#  'jobs': 0.42857142857142855,
#  'require': 0.21428571428571427,
#  'continuous': 0.14285714285714285,
#  'additions': 0.07142857142857142,
#  'laws': 0.07142857142857142,
#  'nature': 0.21428571428571427,
#  'essential': 0.07142857142857142,
#  'obtained': 0.07142857142857142,
#  'however': 0.35714285714285715,
#  'came': 0.21428571428571427,
#  'direct': 0.07142857142857142,
#  'attack': 0.07142857142857142,
#  'leading': 0.2857142857142857,
#  'towards': 0.07142857142857142,
#  'initiatives': 0.14285714285714285,
#  'tasks': 0.07142857142857142,
#  'resisted': 0.07142857142857142,
#  'community': 0.07142857142857142,
#  'issue': 0.14285714285714285,
#  'contentious': 0.07142857142857142,
#  'though': 0.07142857142857142,
#  'analysts': 0.07142857142857142,
#  'resist': 0.07142857142857142,
#  'model': 0.07142857142857142,
#  'partly': 0.07142857142857142,
#  'evolution': 0.14285714285714285,
#  'evolved': 0.07142857142857142,
#  'species': 0.14285714285714285,
#  'foraging': 0.14285714285714285,
#  'hominids': 0.14285714285714285,
#  'bipedal': 0.07142857142857142,
#  'brain': 0.14285714285714285,
#  'mass': 0.21428571428571427,
#  'approximately': 0.21428571428571427,
#  'third': 0.14285714285714285,
#  'tool': 0.21428571428571427,
#  'remained': 0.07142857142857142,
#  'relatively': 0.14285714285714285,
#  'unchanged': 0.07142857142857142,
#  'history': 0.21428571428571427,
#  'ago': 0.21428571428571427,
#  'set': 0.07142857142857142,
#  'behaviors': 0.07142857142857142,
#  'emerged': 0.14285714285714285,
#  'believed': 0.14285714285714285,
#  'archaeologists': 0.14285714285714285,
#  'connected': 0.07142857142857142,
#  'emergence': 0.14285714285714285,
#  'fully': 0.07142857142857142,
#  'language': 0.07142857142857142,
#  'started': 0.07142857142857142,
#  'primitive': 0.07142857142857142,
#  'stone': 0.6428571428571429,
#  'millions': 0.07142857142857142,
#  'earliest': 0.21428571428571427,
#  'little': 0.07142857142857142,
#  'fractured': 0.07142857142857142,
#  'rock': 0.07142857142857142,
#  'pressure': 0.07142857142857142,
#  'flaking': 0.07142857142857142,
#  'provided': 0.14285714285714285,
#  'much': 0.14285714285714285,
#  'finer': 0.07142857142857142,
#  'utilization': 0.07142857142857142,
#  'energy': 0.21428571428571427,
#  'source': 0.07142857142857142,
#  'profound': 0.07142857142857142,
#  'uses': 0.21428571428571427,
#  'turning': 0.07142857142857142,
#  'point': 0.21428571428571427,
#  'humankind': 0.14285714285714285,
#  'date': 0.21428571428571427,
#  'evidence': 0.14285714285714285,
#  'burnt': 0.07142857142857142,
#  'animal': 0.21428571428571427,
#  'bones': 0.07142857142857142,
#  'cradle': 0.07142857142857142,
#  'suggests': 0.14285714285714285,
#  'domestication': 0.07142857142857142,
#  'occurred': 0.14285714285714285,
#  'scholarly': 0.07142857142857142,
#  'consensus': 0.07142857142857142,
#  'indicates': 0.07142857142857142,
#  'homo': 0.14285714285714285,
#  'erectus': 0.07142857142857142,
#  'controlled': 0.07142857142857142,
#  'ka': 0.2857142857142857,
#  'fueled': 0.07142857142857142,
#  'wood': 0.21428571428571427,
#  'charcoal': 0.14285714285714285,
#  'cook': 0.07142857142857142,
#  'increase': 0.21428571428571427,
#  'digestibility': 0.07142857142857142,
#  'improving': 0.14285714285714285,
#  'nutrient': 0.07142857142857142,
#  'broadening': 0.07142857142857142,
#  'number': 0.21428571428571427,
#  'foods': 0.07142857142857142,
#  'eaten': 0.07142857142857142,
#  'advances': 0.2857142857142857,
#  'made': 0.2857142857142857,
#  'paleolithic': 0.14285714285714285,
#  'era': 0.2857142857142857,
#  'shelter': 0.07142857142857142,
#  'adoption': 0.14285714285714285,
#  'dated': 0.07142857142857142,
#  'exactly': 0.07142857142857142,
#  'key': 0.14285714285714285,
#  'progressed': 0.07142857142857142,
#  'dwellings': 0.07142857142857142,
#  'became': 0.14285714285714285,
#  'sophisticated': 0.14285714285714285,
#  'elaborate': 0.07142857142857142,
#  'constructing': 0.07142857142857142,
#  'temporary': 0.07142857142857142,
#  'huts': 0.07142857142857142,
#  'adapted': 0.07142857142857142,
#  'fur': 0.07142857142857142,
#  'hides': 0.07142857142857142,
#  'hunted': 0.07142857142857142,
#  'animals': 0.07142857142857142,
#  'expand': 0.07142857142857142,
#  'colder': 0.07142857142857142,
#  'regions': 0.07142857142857142,
#  'began': 0.21428571428571427,
#  'migrate': 0.07142857142857142,
#  'africa': 0.07142857142857142,
#  'continents': 0.07142857142857142,
#  'eurasia': 0.07142857142857142,
#  'ascent': 0.07142857142857142,
#  'earnest': 0.07142857142857142,
#  'period': 0.2857142857142857,
#  'age': 0.14285714285714285,
#  'polished': 0.14285714285714285,
#  'axes': 0.14285714285714285,
#  'major': 0.14285714285714285,
#  'advance': 0.07142857142857142,
#  'forest': 0.07142857142857142,
#  'clearance': 0.07142857142857142,
#  'large': 0.14285714285714285,
#  'farms': 0.07142857142857142,
#  'greatly': 0.14285714285714285,
#  'originally': 0.07142857142857142,
#  'preceding': 0.07142857142857142,
#  'mesolithic': 0.07142857142857142,
#  'areas': 0.21428571428571427,
#  'ireland': 0.07142857142857142,
#  'agriculture': 0.14285714285714285,
#  'fed': 0.07142857142857142,
#  'larger': 0.07142857142857142,
#  'populations': 0.07142857142857142,
#  'transition': 0.07142857142857142,
#  'sedentism': 0.07142857142857142,
#  'simultaneously': 0.14285714285714285,
#  'raising': 0.14285714285714285,
#  'children': 0.14285714285714285,
#  'infants': 0.07142857142857142,
#  'longer': 0.07142857142857142,
#  'carried': 0.07142857142857142,
#  'nomadic': 0.07142857142857142,
#  'ones': 0.14285714285714285,
#  'must': 0.07142857142857142,
#  'contribute': 0.07142857142857142,
#  'labor': 0.35714285714285715,
#  'crops': 0.07142857142857142,
#  'readily': 0.07142857142857142,
#  'hunter': 0.07142857142857142,
#  'gatherer': 0.07142857142857142,
#  'population': 0.07142857142857142,
#  'availability': 0.14285714285714285,
#  'specialization': 0.07142857142857142,
#  'triggered': 0.07142857142857142,
#  'progression': 0.07142857142857142,
#  'villages': 0.07142857142857142,
#  'first': 0.7142857142857143,
#  'cities': 0.07142857142857142,
#  'uruk': 0.07142857142857142,
#  'civilizations': 0.07142857142857142,
#  'sumer': 0.07142857142857142,
#  'specifically': 0.07142857142857142,
#  'increasingly': 0.2857142857142857,
#  'hierarchical': 0.07142857142857142,
#  'structures': 0.07142857142857142,
#  'specialized': 0.07142857142857142,
#  'trade': 0.21428571428571427,
#  'amongst': 0.14285714285714285,
#  'adjacent': 0.07142857142857142,
#  'cultures': 0.07142857142857142,
#  'collective': 0.07142857142857142,
#  'action': 0.07142857142857142,
#  'overcome': 0.14285714285714285,
#  'environmental': 0.21428571428571427,
#  'irrigation': 0.21428571428571427,
#  'thought': 0.07142857142857142,
#  'played': 0.07142857142857142,
#  'role': 0.21428571428571427,
#  'continuing': 0.07142857142857142,
#  'improvements': 0.07142857142857142,
#  'led': 0.35714285714285715,
#  'furnace': 0.07142857142857142,
#  'bellows': 0.07142857142857142,
#  'ability': 0.14285714285714285,
#  'smelt': 0.07142857142857142,
#  'forge': 0.07142857142857142,
#  'gold': 0.07142857142857142,
#  'copper': 0.35714285714285715,
#  'silver': 0.07142857142857142,
#  'lead': 0.14285714285714285,
#  'native': 0.21428571428571427,
#  'metals': 0.14285714285714285,
#  'pure': 0.07142857142857142,
#  'advantages': 0.07142857142857142,
#  'bone': 0.07142857142857142,
#  'quickly': 0.07142857142857142,
#  'apparent': 0.07142857142857142,
#  'probably': 0.21428571428571427,
#  'near': 0.07142857142857142,
#  'naturally': 0.07142857142857142,
#  'occur': 0.14285714285714285,
#  'amounts': 0.14285714285714285,
#  'ores': 0.07142857142857142,
#  'quite': 0.07142857142857142,
#  'metal': 0.07142857142857142,
#  'easily': 0.14285714285714285,
#  'burned': 0.07142857142857142,
#  'fires': 0.07142857142857142,
#  'eventually': 0.14285714285714285,
#  'working': 0.07142857142857142,
#  'alloys': 0.14285714285714285,
#  'bronze': 0.07142857142857142,
#  'brass': 0.07142857142857142,
#  'bce': 1.0,
#  'iron': 0.125,
#  'steel': 0.125,
#  'dates': 0.25,
#  'meanwhile': 0.125,
#  'learning': 0.25,
#  'harness': 0.125,
#  'wind': 0.125,
#  'power': 0.75,
#  'sailing': 0.125,
#  'ship': 0.25,
#  'record': 0.125,
#  'sail': 0.125,
#  'nile': 0.25,
#  'boat': 0.125,
#  'dating': 0.375,
#  'millennium': 0.125,
#  'egyptians': 0.125,
#  'annual': 0.125,
#  'flooding': 0.125,
#  'irrigate': 0.125,
#  'lands': 0.125,
#  'gradually': 0.125,
#  'regulate': 0.125,
#  'purposely': 0.125,
#  'built': 0.5,
#  'channels': 0.125,
#  'catch': 0.125,
#  'basins': 0.125,
#  'ancient': 0.75,
#  'sumerians': 0.25,
#  'mesopotamia': 0.375,
#  'canals': 0.125,
#  'levees': 0.125,
#  'divert': 0.125,
#  'water': 0.625,
#  'tigris': 0.125,
#  'euphrates': 0.125,
#  'rivers': 0.125,
#  'invented': 0.5,
#  'independently': 0.125,
#  'nearly': 0.375,
#  'present': 0.125,
#  'day': 0.125,
#  'iraq': 0.125,
#  'northern': 0.125,
#  'caucasus': 0.125,
#  'maykop': 0.125,
#  'central': 0.125,
#  'europe': 0.125,
#  'estimates': 0.375,
#  'range': 0.125,
#  'experts': 0.125,
#  'putting': 0.125,
#  'closer': 0.125,
#  'oldest': 0.375,
#  'artifacts': 0.125,
#  'drawings': 0.25,
#  'depicting': 0.125,
#  'wheeled': 0.375,
#  'carts': 0.25,
#  'millennia': 0.125,
#  'ljubljana': 0.125,
#  'marshes': 0.125,
#  'slovenia': 0.125,
#  'revolutionized': 0.25,
#  'take': 0.125,
#  'long': 0.5,
#  'discover': 0.125,
#  'wagons': 0.125,
#  'carry': 0.125,
#  'heavy': 0.25,
#  'loads': 0.125,
#  'potter': 0.125,
#  'pottery': 0.375,
#  'city': 0.25,
#  'ur': 0.25,
#  'even': 0.5,
#  'older': 0.25,
#  'fragments': 0.125,
#  'thrown': 0.125,
#  'area': 0.125,
#  'fast': 0.125,
#  'rotary': 0.125,
#  'potters': 0.125,
#  'wheels': 0.25,
#  'enabled': 0.125,
#  'transformer': 0.125,
#  'windmills': 0.25,
#  'treadmills': 0.125,
#  'nonhuman': 0.125,
#  'derived': 0.125,
#  'travois': 0.125,
#  'iran': 0.125,
#  'constructed': 0.125,
#  'roadways': 0.125,
#  'paved': 0.375,
#  'streets': 0.125,
#  'circa': 0.125,
#  'timber': 0.125,
#  'roads': 0.125,
#  'swamps': 0.125,
#  'glastonbury': 0.125,
#  'england': 0.125,
#  'distance': 0.125,
#  'road': 0.75,
#  'spanned': 0.125,
#  'miles': 0.125,
#  'persian': 0.125,
#  'gulf': 0.125,
#  'mediterranean': 0.125,
#  'sea': 0.125,
#  'partially': 0.125,
#  'maintained': 0.125,
#  'minoans': 0.125,
#  'island': 0.375,
#  'crete': 0.125,
#  'fifty': 0.125,
#  'kilometer': 0.125,
#  'thirty': 0.125,
#  'mile': 0.125,
#  'palace': 0.375,
#  'gortyn': 0.125,
#  'south': 0.125,
#  'side': 0.375,
#  'mountains': 0.125,
#  'knossos': 0.25,
#  'north': 0.125,
#  'unlike': 0.125,
#  'earlier': 0.125,
#  'minoan': 0.375,
#  'completely': 0.125,
#  'private': 0.25,
#  'homes': 0.25,
#  'running': 0.125,
#  'bathtub': 0.125,
#  'virtually': 0.125,
#  'identical': 0.125,
#  'unearthed': 0.125,
#  'several': 0.25,
#  'toilets': 0.25,
#  'flushed': 0.125,
#  'pouring': 0.125,
#  'drain': 0.125,
#  'romans': 0.25,
#  'public': 0.25,
#  'flush': 0.125,
#  'emptied': 0.125,
#  'extensive': 0.125,
#  'sewage': 0.125,
#  'primary': 0.125,
#  'sewer': 0.125,
#  'rome': 0.125,
#  'cloaca': 0.125,
#  'maxima': 0.125,
#  'construction': 0.5,
#  'sixth': 0.125,
#  'still': 0.375,
#  'aqueducts': 0.25,
#  'transport': 0.375,
#  'across': 0.125,
#  'distances': 0.125,
#  'roman': 0.5,
#  'aqueduct': 0.25,
#  'eleventh': 0.125,
#  'final': 0.125,
#  'ce': 0.125,
#  'put': 0.125,
#  'together': 0.125,
#  'extended': 0.125,
#  'kilometers': 0.25,
#  'less': 0.125,
#  'seventy': 0.125,
#  'ground': 0.125,
#  'supported': 0.125,
#  'arches': 0.125,
#  'middle': 0.125,
#  'ages': 0.125,
#  'silk': 0.125,
#  'horse': 0.125,
#  'collar': 0.125,
#  'horseshoes': 0.125,
#  'hundred': 0.125,
#  'empire': 0.125,
#  'medieval': 0.125,
#  'saw': 0.25,
#  'lever': 0.125,
#  'screw': 0.125,
#  'pulley': 0.125,
#  'complicated': 0.125,
#  'wheelbarrow': 0.125,
#  'clocks': 0.125,
#  'renaissance': 0.125,
#  'brought': 0.375,
#  'forth': 0.125,
#  'facilitated': 0.125,
#  'greater': 0.125,
#  'associated': 0.25,
#  'cycle': 0.125,
#  'mutual': 0.125,
#  'advancement': 0.25,
#  'advancements': 0.25,
#  'steady': 0.125,
#  'supply': 0.25,
#  'followed': 0.125,
#  'wider': 0.125,
#  'starting': 0.125,
#  'kingdom': 0.125,
#  'great': 0.125,
#  'particularly': 0.375,
#  'manufacturing': 0.25,
#  'mining': 0.125,
#  'metallurgy': 0.125,
#  'driven': 0.125,
#  'steam': 0.125,
#  'took': 0.125,
#  'step': 0.125,
#  'harnessing': 0.125,
#  'electricity': 0.125,
#  'electric': 0.125,
#  'motor': 0.125,
#  'light': 0.125,
#  'bulb': 0.125,
#  'countless': 0.125,
#  'others': 0.125,
#  'concepts': 0.25,
#  'powered': 0.125,
#  'flight': 0.125,
#  'medicine': 0.375,
#  'chemistry': 0.125,
#  'physics': 0.25,
#  'skyscrapers': 0.125,
#  'urban': 0.125,
#  'whose': 0.125,
#  'inhabitants': 0.125,
#  'rely': 0.125,
#  'motors': 0.125,
#  'improved': 0.125,
#  'telegraph': 0.125,
#  'radio': 0.125,
#  'television': 0.125,
#  'centuries': 0.125,
#  'transportation': 0.25,
#  'airplane': 0.125,
#  'automobile': 0.125,
#  'host': 0.125,
#  'nuclear': 0.375,
#  'fission': 0.125,
#  'miniaturized': 0.125,
#  'utilizing': 0.125,
#  'transistors': 0.125,
#  'integrated': 0.125,
#  'circuits': 0.125,
#  'information': 0.375,
#  'subsequently': 0.125,
#  'creation': 0.125,
#  'ushered': 0.125,
#  'able': 0.25,
#  'explore': 0.125,
#  'satellites': 0.125,
#  'telecommunication': 0.125,
#  'manned': 0.125,
#  'missions': 0.125,
#  'going': 0.25,
#  'moon': 0.125,
#  'open': 0.25,
#  'heart': 0.125,
#  'surgery': 0.125,
#  'stem': 0.125,
#  'cell': 0.125,
#  'therapy': 0.125,
#  'along': 0.125,
#  'medications': 0.125,
#  'treatments': 0.125,
#  'organizations': 0.125,
#  'maintain': 0.125,
#  'entire': 0.25,
#  'support': 0.375,
#  'succeeding': 0.125,
#  'generations': 0.125,
#  'relies': 0.125,
#  'training': 0.25,
#  'designers': 0.125,
#  'builders': 0.125,
#  'maintainers': 0.125,
#  'users': 0.125,
#  'general': 0.25,
#  'moreover': 0.125,
#  'become': 0.25,
#  'architecture': 0.125,
#  'generally': 0.375,
#  'technicism': 0.25,
#  'belief': 0.125,
#  'societies': 0.75,
#  'taken': 0.25,
#  'extreme': 0.125,
#  'reflects': 0.125,
#  'fundamental': 0.375,
#  'attitude': 0.125,
#  'seeks': 0.125,
#  'reality': 0.125,
#  'resolve': 0.125,
#  'words': 0.125,
#  'beings': 0.25,
#  'someday': 0.125,
#  'master': 0.125,
#  'possibly': 0.125,
#  'future': 0.625,
#  ...}

# %% [markdown]
# # Calculate Sentence Score

# %%
sent2score = {}

# %%
for sentence in sentences:
    for word in nltk.word_tokenize(sentence.lower()):
        if word in word2count.keys():
            if len(sentence.split(' ')) < 25 :
                if sentence not in sent2score.keys():
                    sent2score[sentence] = word2count[word]
                else:
                    sent2score[sentence] += word2count[word]

# %%
sent2score
# Out:
# {'Technology can be the knowledge of techniques, processes, and the like, or it can be embedded in machines to allow for operation without detailed knowledge of their workings.': 2.870967741935484,
#  'The simplest form of technology is the development and use of basic tools.': 7.217391304347826,
#  'Developments in historic times, including the printing press, the telephone, and the Internet, have lessened physical barriers to communication and allowed humans to interact freely on a global scale.': 3.888888888888889,
#  'Technology has many effects.': 3.3333333333333335,
#  "It has helped develop more advanced economies (including today's global economy) and has allowed the rise of a leisure class.": 4.111111111111111,
#  "Many technological processes produce unwanted by-products known as pollution and deplete natural resources to the detriment of Earth's environment.": 5.948885772167678,
#  'Innovations have always influenced the values of a society and raised new questions of the ethics of technology.': 6.5555555555555545,
#  'Examples include the rise of the notion of efficiency in terms of human productivity, and the challenges of bioethics.': 4.999999999999999,
#  'Philosophical debates have arisen over the use of technology, with disagreements over whether technology improves the human condition or worsens it.': 9.33333333333333,
#  'The use of the term "technology" has changed significantly over the last 200 years.': 6.444444444444444,
#  'The term "technology" rose to prominence in the 20th century in connection with the Second Industrial Revolution.': 6.222222222222221,
#  'The term\'s meanings changed in the early 20th century when American social scientists, beginning with Thorstein Veblen, translated ideas from the German concept of Technik into "technology."': 4.5,
#  'In German and other European languages, a distinction exists between technik and technologie that is absent in English, which usually translates both terms as "technology."': 2.111111111111111,
#  'By the 1930s, "technology" referred not only to the study of the industrial arts but to the industrial arts themselves.': 5.396135265700483,
#  "Bain's definition remains common among scholars today, especially social scientists.": 3.999999999999999,
#  'Scientists and engineers usually prefer to define technology as applied science, rather than as the things that people make and use.': 9.724014336917563,
#  'Dictionaries and scholars have offered a variety of definitions.': 1.0,
#  'Ursula Franklin, in her 1989 "Real World of Technology" lecture, gave another definition of the concept; it is "practice, the way we do things around here."': 3.666666666666666,
#  'The term is often used to imply a specific field of technology, or to refer to high technology or just consumer electronics, rather than technology as a whole.': 6.025089605734766,
#  'Bernard Stiegler, in Technics and Time, 1, defines technology in two ways: as "the pursuit of life by means other than life," and as "organized inorganic matter."': 3.1111111111111107,
#  'Technology can be most broadly defined as the entities, both material and immaterial, created by the application of mental and physical effort in order to achieve some value.': 2.833333333333334,
#  'In this usage, technology refers to tools and machines that may be used to solve real-world problems.': 8.695340501792113,
#  'It is a far-reaching term that may include simple tools, such as a crowbar or wooden spoon, or more complex machines, such as a space station or particle accelerator.': 3.989247311827956,
#  'Tools and machines need not be material; virtual technology, such as computer software and business methods, fall under this definition of technology.': 9.014336917562723,
#  'W. Brian Arthur defines technology in a similarly broad way as "a means to fulfill a human purpose."': 6.666666666666665,
#  'The word "technology" can also be used to refer to a collection of techniques.': 6.408602150537633,
#  'When combined with another term, such as "medical technology" or "space technology," it refers to the state of the respective field\'s knowledge and tools.': 10.855606758832563,
#  '"State-of-the-art technology" refers to the high technology available to humanity in any field.': 6.1269841269841265,
#  'Technology can be viewed as an activity that forms or changes culture.': 3.873015873015874,
#  'Additionally, technology is the application of math, science, and the arts for the benefit of life as it is known.': 6.7398873527905785,
#  'Not all technology enhances culture in a creative way; technology can also help facilitate political oppression and war via tools such as guns.': 11.714285714285712,
#  'As a cultural activity, technology predates both science and engineering, each of which formalize some aspects of technological endeavor.': 7.954518132638749,
#  'The distinction between science, engineering, and technology is not always clear.': 5.454173067076293,
#  'Science is systematic knowledge of the physical or material world gained through observation and experimentation.': 5.087557603686636,
#  'Technologies are not usually exclusively products of science, because they have to satisfy requirements such as utility, usability, and safety.': 4.533538146441373,
#  'The development of technology may draw upon many fields of knowledge, including scientific, engineering, mathematical, linguistic, and historical knowledge, to achieve some practical result.': 11.379483069525143,
#  'Technology is often a consequence of science and engineering, although technology as a human activity precedes the two fields.': 12.136712749615974,
#  'For example, science might study the flow of electrons in electrical conductors by using already-existing tools and knowledge.': 6.849462365591396,
#  'This new-found knowledge may then be used by engineers to create new tools and machines such as semiconductors, computers, and other forms of advanced technology.': 5.854838709677419,
#  'In this sense, scientists and engineers may both be considered technologists; the three fields are often considered as one for the purposes of research and reference.': 4.492063492063491,
#  'This essential new knowledge can be obtained only through basic scientific research."': 4.682606469422739,
#  'In the late-1960s, however, this view came under direct attack, leading towards initiatives to fund science for specific tasks (initiatives resisted by the scientific community).': 3.208909370199693,
#  'The issue remains contentious, though most analysts resist the model that technology simply is a result of scientific research.': 5.646185355862775,
#  'The use of tools by early humans was partly a process of discovery and of evolution.': 8.777777777777777,
#  'Early humans evolved from a species of foraging hominids which were already bipedal, with a brain mass approximately one third of modern humans.': 9.222222222222223,
#  'Tool use remained relatively unchanged for most of early human history.': 6.5396825396825395,
#  'Approximately 50,000 years ago, the use of tools and complex set of behaviors emerged, believed by many archaeologists to be connected to the emergence of fully modern language.': 5.230158730158731,
#  'Hominids started using primitive stone tools millions of years ago.': 5.80952380952381,
#  'The earliest stone tools were little more than a fractured rock, but approximately 75,000 years ago, pressure flaking provided a way to make much finer work.': 4.222222222222222,
#  'The discovery and utilization of fire, a simple energy source with many profound uses, was a turning point in the technological evolution of humankind.': 7.341614906832298,
#  "Other technological advances made during the Paleolithic era were clothing and shelter; the adoption of both technologies cannot be dated exactly, but they were a key to humanity's progress.": 3.686680469289165,
#  'As the Paleolithic era progressed, dwellings became more sophisticated and more elaborate; as early as 380 ka, humans were constructing temporary wood huts.': 5.9523809523809526,
#  'Human\'s technological ascent began in earnest in what is known as the Neolithic Period ("New Stone Age").': 10.10351966873706,
#  'The invention of polished stone axes was a major advance that allowed forest clearance on a large scale to create farms.': 4.984126984126983,
#  'This use of polished stone axes increased greatly in the Neolithic, but were originally used in the preceding Mesolithic in some areas such as Ireland.': 3.6520737327188946,
#  'Agriculture fed larger populations, and the transition to sedentism allowed simultaneously raising more children, as infants no longer needed to be carried, as nomadic ones must.': 2.103174603174603,
#  'Additionally, children could contribute labor to the raising of crops more readily than they could to the hunter-gatherer economy.': 4.222222222222221,
#  'With this increase in population and availability of labor came an increase in labor specialization.': 3.285714285714286,
#  'Native copper does not naturally occur in large amounts, but copper ores are quite common and some of them produce metal easily when burned in wood or charcoal fires.': 2.674603174603175,
#  'Eventually, the working of metals led to the discovery of alloys such as bronze and brass (about 4000 BCE).': 5.111111111111111,
#  'The first uses of iron alloys such as steel dates to around 1800 BCE.': 6.0317460317460325,
#  'Meanwhile, humans were learning to harness other forms of energy.': 3.428571428571429,
#  'The ancient Sumerians in Mesopotamia used a complex system of canals and levees to divert water from the Tigris and Euphrates rivers for irrigation.': 8.570148489503328,
#  'According to archaeologists, the wheel was invented around 4000 BCE probably independently and nearly simultaneously in Mesopotamia (in present-day Iraq), the Northern Caucasus (Maykop culture) and Central Europe.': 5.175691244239631,
#  'Estimates on when this may have occurred range from 5500 to 3000 BCE with most experts putting it closer to 4000 BCE.': 7.035714285714286,
#  'The oldest artifacts with drawings depicting wheeled carts date from about 3500 BCE; however, the wheel may have been in use for millennia before these drawings were made.': 5.787698412698413,
#  'More recently, the oldest-known wooden wheel in the world was found in the Ljubljana marshes of Slovenia.': 4.527777777777778,
#  'The invention of the wheel revolutionized trade and war.': 3.166666666666667,
#  'It did not take long to discover that wheeled wagons could be used to carry heavy loads.': 5.661290322580645,
#  "The ancient Sumerians used the potter's wheel and may have invented it.": 6.522401433691757,
#  'A stone pottery wheel found in the city-state of Ur dates to around 3429 BCE, and even older fragments of wheel-thrown pottery have been found in the same area.': 5.892857142857143,
#  'The first two-wheeled carts were derived from travois and were first used in Mesopotamia and Iran in around 3000 BCE.': 8.907322068612391,
#  'Unlike the earlier road, the Minoan road was completely paved.': 5.25,
#  'Ancient Minoan private homes had running water.': 4.75,
#  'A bathtub virtually identical to modern ones was unearthed at the Palace of Knossos.': 3.3928571428571423,
#  'Several Minoan private homes also had toilets, which could be flushed by pouring water down the drain.': 7.75,
#  'The ancient Romans had many public flush toilets, which emptied into an extensive sewage system.': 5.258064516129032,
#  'The primary sewer in Rome was the Cloaca Maxima; construction began on it in the sixth century BCE and it is still in use today.': 4.450396825396825,
#  'The ancient Romans also had a complex system of aqueducts, which were used to transport water across long distances.': 10.6415770609319,
#  'The first Roman aqueduct was built in 312 BCE.': 5.928571428571429,
#  'The eleventh and final ancient Roman aqueduct was built in 226 CE.': 4.75,
#  'Put together, the Roman aqueducts extended over 450 kilometers, but less than seventy kilometers of this was above ground and supported by arches.': 4.5,
#  'Innovations continued through the Middle Ages with innovations such as silk, the horse collar and horseshoes in the first few hundred years after the fall of the Roman Empire.': 3.547619047619048,
#  'The advancements in technology in this era allowed a more steady supply of food, followed by the wider availability of consumer goods.': 6.180619559651817,
#  'Technology took another step in a second industrial revolution with the harnessing of electricity to create such innovations as the electric motor, light bulb, and countless others.': 4.130952380952381,
#  'Scientific advancement and the discovery of new concepts later allowed for powered flight and advancements in medicine, chemistry, physics, and engineering.': 9.543010752688172,
#  'The rise in technology has led to skyscrapers and broad urban areas whose inhabitants rely on motors to transport them and their food supply.': 7.115079365079365,
#  'Communication was also greatly improved with the invention of the telegraph, telephone, radio and television.': 4.507936507936508,
#  'The late 19th and early 20th centuries saw a revolution in transportation with the invention of the airplane and automobile.': 4.654761904761904,
#  'The 20th century brought a host of innovations.': 2.6666666666666665,
#  'In physics, the discovery of nuclear fission has led to both nuclear weapons and nuclear power.': 6.5476190476190474,
#  'Computers were also invented and later miniaturized utilizing transistors and integrated circuits.': 5.345238095238095,
#  'Information technology subsequently led to the creation of the Internet, which ushered in the current Information Age.': 6.78968253968254,
#  'Humans have also been able to explore space with satellites (later used for telecommunication) and in manned missions going all the way to the moon.': 4.608422939068101,
#  'In medicine, this era brought innovations such as open-heart surgery and later stem cell therapy along with new medications and treatments.': 7.043650793650794,
#  'Modern technology increasingly relies on training and education – their designers, builders, maintainers, and users often require sophisticated general and specific training.': 8.559523809523808,
#  'Generally, technicism is the belief in the utility of technology for improving human societies.': 7.571428571428572,
#  'Taken to an extreme, technicism "reflects a fundamental attitude which seeks to control reality, to resolve all problems with the use of scientific–technological methods and tools."': 4.476254480286738,
#  'In other words, human beings will someday be able to master all problems and possibly even control the future using technology.': 10.40873015873016,
#  'Some, such as Stephen V. Monsma, connect these ideas to the abdication of religion as a higher moral authority.': 2.4722222222222223,
#  'Optimistic assumptions are made by proponents of ideologies such as transhumanism and singularitarianism, which view technological development as generally having beneficial effects for the society and the human condition.': 4.709627329192547,
#  'In these ideologies, technological development is morally good.': 3.792270531400966,
#  'Estimates for the date of this Singularity vary, but prominent futurist Ray Kurzweil estimates the Singularity will occur in 2045.': 8.214285714285715,
#  'Going from one epoch to the next is a Singularity in its own right, and a period of speeding up precedes it.': 7.5,
#  'Each epoch takes a shorter time, which means the whole history of the universe is one giant Singularity event.': 9.015873015873016,
#  'Some critics see these ideologies as examples of scientism and techno-utopianism and fear the notion of human enhancement and technological singularity which they support.': 10.385265700483094,
#  'Some have described Karl Marx as a techno-optimist.': 1.5,
#  'On the somewhat skeptical side are certain philosophers like Herbert Marcuse and John Zerzan, who believe that technological societies are inherently flawed.': 9.87540906965872,
#  'They suggest that the inevitable result of such a society is to become evermore technological at the cost of freedom and psychological health.': 8.405106970324361,
#  'Many, such as the Luddites and prominent philosopher Martin Heidegger, hold serious, although not entirely, deterministic reservations about technology (see "The Question Concerning Technology" ).': 7.642857142857142,
#  'According to Heidegger scholars Hubert Dreyfus and Charles Spinosa, "Heidegger does not oppose technology.': 9.331541218637993,
#  "Indeed, he promises that 'when we once open ourselves expressly to the essence of technology, we find ourselves unexpectedly taken into a freeing claim.'": 8.0,
#  'What this entails is a more complex relationship to technology than either techno-optimists or techno-pessimists tend to allow."': 5.073476702508961,
#  'Nikolas Kompridis has also written about the dangers of new technology, such as genetic engineering, nanotechnology, synthetic biology, and robotics.': 14.277777777777779,
#  'He warns that these technologies introduce unprecedented new challenges to human beings, including the possibility of the permanent alteration of our biological nature.': 10.53968253968254,
#  'These concerns are shared by other philosophers, scientists and public intellectuals who have written about similar issues (e.g.': 7.444444444444445,
#  'Francis Fukuyama, Jürgen Habermas, William Joy, and Michael Sandel).': 4.5,
#  "Another prominent critic of technology is Hubert Dreyfus, who has published books such as On the Internet and What Computers Still Can't Do.": 10.345238095238095,
#  'There are also subcultures that disapprove of some or most technology, such as self-identified off-gridders.': 4.785714285714286,
#  'The ecovillage movement emerged in part due to this concern.': 2.642857142857143,
#  'This section mainly focuses on American concerns even if it can reasonably be generalized to other Western countries.': 7.166666666666666,
#  'The inadequate quantity and quality of American jobs is one of the most fundamental economic challenges we face.': 6.972222222222221,
#  'His thesis appears to be a third way between optimism and skepticism.': 3.2857142857142856,
#  'Essentially, he stands for a neutral approach of the linkage between technology and American issues concerning unemployment and declining wages.': 11.666666666666668,
#  'He uses two main arguments to defend his point.': 2.9126984126984126,
#  'First, because of recent technological advances, an increasing number of workers are losing their jobs.': 8.698757763975156,
#  'Yet, scientific evidence fails to clearly demonstrate that technology has displaced so many workers that it has created more problems than it has solved.': 10.828725038402458,
#  'Second, studies have not shown clear links between recent technology advances and the wage trends of the last decades.': 8.412698412698411,
#  'Continuous studies have shown that increased BMI and weight gain are associated with people who spend long hours online and not exercising frequently.': 8.785714285714285,
#  'Heavy Internet use is also displayed in the school lower grades of those who use it in excessive amounts.': 10.896825396825395,
#  'It has also been noted that the use of mobile phones whilst driving has increased the occurrence of road accidents — particularly amongst teen drivers.': 6.240079365079366,
#  'In this context, mass media and technology have a negative impact on people, on both their mental and physical health.': 8.158730158730158,
#  'What is the difference between a wheel or a compass and cooking machines such as an oven or a gas stove?': 5.256272401433692,
#  'Can we consider all of them, only a part of them, or none of them as technologies?': 3.071428571428571,
#  'Technology is often considered too narrowly; according to Hughes, "Technology is a creative process involving human ingenuity".': 12.355350742447516,
#  'They have often supposed that technology is easily controllable and this assumption has to be thoroughly questioned.': 5.896825396825397,
#  'For instance, Evgeny Morozov particularly challenges two concepts: "Internet-centrism" and "solutionism."': 5.361111111111111,
#  'Internet-centrism refers to the idea that our society is convinced that the Internet is one of the most stable and coherent forces.': 6.476190476190476,
#  'Solutionism is the ideology that every social issue can be solved thanks to technology and especially thanks to the internet.': 9.674603174603174,
#  'In fact, technology intrinsically contains uncertainties and limitations.': 5.5,
#  'According to Alexis Madrigal\'s review of Morozov\'s theory, to ignore it will lead to "unexpected consequences that could eventually cause more damage than the problems they seek to address."': 4.673707117255504,
#  'Benjamin R. Cohen and Gwen Ottinger also discussed the multivalent effects of technology.': 7.833333333333333,
#  'Therefore, recognition of the limitations of technology, and more broadly, scientific knowledge, is needed – especially in cases dealing with environmental justice and health issues.': 6.88978494623656,
#  'Ottinger continues this reasoning and argues that the ongoing recognition of the limitations of scientific knowledge goes hand in hand with scientists and engineers’ new comprehension of their role.': 6.325396825396825,
#  'Such an approach of technology and science "[require] technical professionals to conceive of their roles in the process differently.': 8.057347670250897,
#  '[They have to consider themselves as] collaborators in research and problem solving rather than simply providers of information and technical solutions."': 7.027777777777779,
#  'Technology is properly defined as any application of science to accomplish a function.': 6.279569892473118,
#  'It was not economic-based planning.': 1.0,
#  'The use of basic technology is also a feature of other animal species apart from humans.': 9.704623878536923,
#  'These include primates such as chimpanzees, some dolphin communities, and crows.': 9.555555555555555,
#  'The ability to make and use tools was once considered a defining characteristic of the genus Homo.': 12.126984126984127,
#  'However, the discovery of tool construction among chimpanzees and related primates has discarded the notion of the use of technology as unique to humans.': 18.476190476190474,
#  'For example, researchers have observed wild chimpanzees utilising tools for foraging: some of the tools used include leaf sponges, termite fishing probes, pestles and levers.': 15.28699436763953,
#  'West African chimpanzees also use stone hammers and anvils for cracking nuts, as do capuchin monkeys of Boa Vista, Brazil.': 29.285714285714285,
#  'Theories of technology often attempt to predict the future of technology based on the high technology and science of the time.': 18.69623655913978,
#  "As with all predictions of the future, however, technology's is uncertain.": 7.964285714285714}

# %% [markdown]
# # Getting Summary

# %%
best_sentences = heapq.nlargest(10,sent2score,key=sent2score.get)

# %%
print('---------------------------------------------------------')
for s in best_sentences:
    print(s)
# Out:
# ---------------------------------------------------------
# West African chimpanzees also use stone hammers and anvils for cracking nuts, as do capuchin monkeys of Boa Vista, Brazil.
# Theories of technology often attempt to predict the future of technology based on the high technology and science of the time.
# However, the discovery of tool construction among chimpanzees and related primates has discarded the notion of the use of technology as unique to humans.
# For example, researchers have observed wild chimpanzees utilising tools for foraging: some of the tools used include leaf sponges, termite fishing probes, pestles and levers.
# Nikolas Kompridis has also written about the dangers of new technology, such as genetic engineering, nanotechnology, synthetic biology, and robotics.
# Technology is often considered too narrowly; according to Hughes, "Technology is a creative process involving human ingenuity".
# Technology is often a consequence of science and engineering, although technology as a human activity precedes the two fields.
# The ability to make and use tools was once considered a defining characteristic of the genus Homo.
# Not all technology enhances culture in a creative way; technology can also help facilitate political oppression and war via tools such as guns.
# Essentially, he stands for a neutral approach of the linkage between technology and American issues concerning unemployment and declining wages.
